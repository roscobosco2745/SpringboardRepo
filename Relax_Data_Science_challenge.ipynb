# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
engagement = pd.read_csv('takehome_user_engagement.csv')

# %%
engagement.head()
# Out:
#             time_stamp  user_id  visited
# 0  2014-04-22 03:53:30        1        1
# 1  2013-11-15 03:45:04        2        1
# 2  2013-11-29 03:45:04        2        1
# 3  2013-12-09 03:45:04        2        1
# 4  2013-12-25 03:45:04        2        1

# %%
engagement.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207917 entries, 0 to 207916
# Data columns (total 3 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   time_stamp  207917 non-null  datetime64[ns]
#  1   user_id     207917 non-null  int64
#  2   visited     207917 non-null  int64
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 4.8 MB

# %%
engagement['time_stamp'] = pd.to_datetime(engagement['time_stamp'])

# %%
engagement.dtypes
# Out:
# time_stamp    datetime64[ns]
# user_id                int64
# visited                int64
# dtype: object

# %%
engagement['result'] = engagement.groupby('user_id')['time_stamp'].rolling(2).apply(lambda x: x.iloc[1].dt.days - x.iloc[0].dt.days)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File F:\Anaconda_Installation\envs\tf\lib\site-packages\pandas\core\window\rolling.py:450, in BaseWindow._apply_series(self, homogeneous_func, name)
#     449 try:
# --> 450     values = self._prep_values(obj._values)
#     451 except (TypeError, NotImplementedError) as err:
#
# File F:\Anaconda_Installation\envs\tf\lib\site-packages\pandas\core\window\rolling.py:360, in BaseWindow._prep_values(self, values)
#     359 if needs_i8_conversion(values.dtype):
# --> 360     raise NotImplementedError(
#     361         f"ops for {type(self).__name__} for this "
#     362         f"dtype {values.dtype} are not implemented"
#     363     )
#     364 # GH #12373 : rolling functions error on float32 data
#     365 # make sure the data is coerced to float64
#
# ...

# %%
engagement_userid_group
# Out:
# user_id
# 1        0        2014-04-22 03:53:30
# 2        1        2013-11-15 03:45:04
#          2        2013-11-29 03:45:04
#          3        2013-12-09 03:45:04
#          4        2013-12-25 03:45:04
#                           ...
# 11996    207912   2013-09-06 06:14:15
# 11997    207913   2013-01-15 18:28:37
# 11998    207914   2014-04-27 12:45:16
# 11999    207915   2012-06-02 11:55:59
# 12000    207916   2014-01-26 08:57:12
# Name: time_stamp, Length: 207917, dtype: datetime64[ns]

# %%
user = pd.read_csv('takehome_users.csv', encoding = 'latin)

# %%
user.head()
# Out:
#    object_id        creation_time               name  \
# 0          1  2014-04-22 03:53:30     Clausen August
# 1          2  2013-11-15 03:45:04      Poole Matthew
# 2          3  2013-03-19 23:14:52  Bottrill Mitchell
# 3          4  2013-05-21 08:09:28    Clausen Nicklas
# 4          5  2013-01-17 10:14:20          Raw Grace
#
#                         email creation_source  last_session_creation_time  \
# 0    AugustCClausen@yahoo.com    GUEST_INVITE                1.398139e+09
# 1      MatthewPoole@gustr.com      ORG_INVITE                1.396238e+09
# 2  MitchellBottrill@gustr.com      ORG_INVITE                1.363735e+09
# 3   NicklasSClausen@yahoo.com    GUEST_INVITE                1.369210e+09
# 4          GraceRaw@yahoo.com    GUEST_INVITE                1.358850e+09
#
#    opted_in_to_mailing_list  enabled_for_marketing_drip  org_id  \
# 0                         1                           0      11
# 1                         0                           0       1
# ...

# %%
user.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   object_id                   12000 non-null  int64
#  1   creation_time               12000 non-null  object
#  2   name                        12000 non-null  object
#  3   email                       12000 non-null  object
#  4   creation_source             12000 non-null  object
#  5   last_session_creation_time  8823 non-null   float64
#  6   opted_in_to_mailing_list    12000 non-null  int64
#  7   enabled_for_marketing_drip  12000 non-null  int64
#  8   org_id                      12000 non-null  int64
#  9   invited_by_user_id          6417 non-null   float64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 937.6+ KB

# %%
user_engagement_merge = user.merge(engagement, left_on = 'object_id', right_on = 'user_id')

# %%
user_engagement_merge
# Out:
#         object_id        creation_time            name  \
# 0               1  2014-04-22 03:53:30  Clausen August
# 1               2  2013-11-15 03:45:04   Poole Matthew
# 2               2  2013-11-15 03:45:04   Poole Matthew
# 3               2  2013-11-15 03:45:04   Poole Matthew
# 4               2  2013-11-15 03:45:04   Poole Matthew
# ...           ...                  ...             ...
# 207912      11996  2013-09-06 06:14:15    Meier Sophia
# 207913      11997  2013-01-10 18:28:37   Fisher Amelie
# 207914      11998  2014-04-27 12:45:16     Haynes Jake
# 207915      11999  2012-05-31 11:55:59    Faber Annett
# 207916      12000  2014-01-26 08:57:12      Lima Thaís
#
#                             email     creation_source  \
# 0        AugustCClausen@yahoo.com        GUEST_INVITE
# 1          MatthewPoole@gustr.com          ORG_INVITE
# 2          MatthewPoole@gustr.com          ORG_INVITE
# 3          MatthewPoole@gustr.com          ORG_INVITE
# ...

# %%
len(engagement_grouped.index)
# Out:
# 8823

# %%
merger = engagement_grouped.merge(user, left_on = 'user_id', right_on = 'object_id')

# %%
merger
# Out:
#       visited  object_id        creation_time               name  \
# 0           1          1  2014-04-22 03:53:30     Clausen August
# 1          14          2  2013-11-15 03:45:04      Poole Matthew
# 2           1          3  2013-03-19 23:14:52  Bottrill Mitchell
# 3           1          4  2013-05-21 08:09:28    Clausen Nicklas
# 4           1          5  2013-01-17 10:14:20          Raw Grace
# ...       ...        ...                  ...                ...
# 8818        1      11996  2013-09-06 06:14:15       Meier Sophia
# 8819        1      11997  2013-01-10 18:28:37      Fisher Amelie
# 8820        1      11998  2014-04-27 12:45:16        Haynes Jake
# 8821        1      11999  2012-05-31 11:55:59       Faber Annett
# 8822        1      12000  2014-01-26 08:57:12         Lima Thaís
#
#                            email     creation_source  \
# 0       AugustCClausen@yahoo.com        GUEST_INVITE
# 1         MatthewPoole@gustr.com          ORG_INVITE
# ...

# %% [markdown]
# ### I was not able to actually show which users are adopted users but the plan to accomplish the mission was as follows:  First I create two dataframes, the 'engagement' dataframe which tells how when a user logs on, and the 'user' dataframe which has information about the user.  Then I use the 'engagement' dataframe to determine which users are adopted users by grouping by user and creating a rolling window, three rows wide, and checking to see if the difference between the two values is at most 7 days.  Each user meeting this requirement would receive a '1' for "adopted user".  Next I would merge the two dataframes using the user_id column from the 'engagement' dataframe and the object_id column from the 'user' dataframe.  Then I would take steps to build a machine learning model by inspecting the data for missing values, creating visuals to investigate the nature of the data, engineering predictor columns as necessary and then building a model.  Since the target would be if a user is an adopted user or not, I would use a binary classifier, most likely a Random Forest Classifier because it protects against overfitting to a large degree.  Finally I would check the metrics (accuracy and precision) and finally determine which features contributed most to the outcome.
